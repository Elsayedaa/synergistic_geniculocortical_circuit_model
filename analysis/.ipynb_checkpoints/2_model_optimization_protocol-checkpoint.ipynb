# %%
import os
import pickle
from itertools import combinations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams, cycler
from matplotlib.cm import ScalarMappable
import seaborn as sns
import tensorflow as tf
from scipy.stats import pearsonr, gaussian_kde
from sklearn.decomposition import PCA
import sys
sys.path.append(os.path.join('c:\\', *os.getcwd().split('\\')[1:-1]))
from sgcc import *

# %%
plt.rcParams['figure.dpi'] = 300
fontsize = 8
linewidth = 0.5

# %%
X = tf.convert_to_tensor([0.02,0.04,0.08,0.1,0.12,0.16,0.2,0.24,0.28,0.32], dtype = tf.float32)

# %%
v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'project_datafiles', 'v1_ori_phase_condition_pcascores_wcomp.pkl')
v1_scores = pd.read_pickle(v1_xs_file)
v1_scores_condition_averaged = np.array([np.array(x) for x in v1_scores.scores.values]).mean(0)
Y_true = v1_scores_condition_averaged[:2,:,:].transpose(0,2,1)

# %%
Y_true = v1_scores_condition_averaged[:2,:,:].transpose(0,2,1)

# %%
def gaussian(
    support, # domain of the function
    ctr, # mean of the function
    amp, # amplitude of the function
    mid, # midline of the function
    std # bandwidth parameter
):

    f = tf.math.exp(-1*(((support-ctr)**2)/(2*std**2)))

    return mid+(amp*f)

# %%
g1 = gaussian(
    X,
    0.05,
    3.5,
    1.6,
    0.03
)

g2 = gaussian(
    X,
    0.05,
    1.5,
    0.6,
    0.02
)

# %%
b = [
    (0.05, 0.05),
    (1.5, 3.5),
    (0.6, 1.6),
    (0.02, 0.03),
]

# %%
plt.plot(X, Y_true.max(2)[0])
plt.plot(X, g1, '--')
plt.plot(X, Y_true.max(2)[1])
plt.plot(X, g2, '--')

# %%
b = [
    (0.05, 0.05),
    (1.5, 3.5),
    (0.6, 1.6),
    (0.02, 0.03),
]

# %%
param_bounds = {
    "fts": [0, 175],
    "t": [40, 125],
    "ampc": [0.01, 0.1],
    'ampm': [0,3],
    "ampg": [0.1, 4],
    "ampw": [0.01,0.08],
    "d": [10, 40],
    "inh_d": [0, 40],
    "inh_w": [0, 3],
}

# %% [markdown]
# ## 1) Initial optimization

# %%
sgcc = SGCCircuit(param_bounds)

# %%
sgcc.initialize_random_parameters(n_v1=2, n_lgn=3, n_sample=1000)

# %%
optimizer = Optimize(sgcc, epochs=10000, loss_threshold=0)
# Out:
# Optimizer initialized with <keras.optimizers.optimizer_v2.adam.Adam object at 0x000001D3141067C0>

# %%
loss_decay = optimizer.fit(X, Y_true)
# Out:
# Training step = 0, N_exploration_samples = 1000,
# min_loss = 0.7026255130767822
# med_loss = 11.855133056640625
# max_loss = 94.93697357177734
#
# Training step = 100, N_exploration_samples = 1000,
# min_loss = 0.4597170948982239
# med_loss = 8.942556381225586
# max_loss = 84.69989776611328
#
# Training step = 200, N_exploration_samples = 1000,
# min_loss = 0.3586830198764801
# med_loss = 6.943807601928711
# max_loss = 75.12287139892578
#
# Training step = 300, N_exploration_samples = 1000,
# min_loss = 0.3070581555366516
# med_loss = 5.368335723876953
# max_loss = 66.23435974121094
#
# Training step = 400, N_exploration_samples = 1000,
# min_loss = 0.2562495172023773
# med_loss = 4.205423831939697
# max_loss = 58.0712890625
#
# Training step = 500, N_exploration_samples = 1000,
# min_loss = 0.21808698773384094
# med_loss = 3.333883762359619
# max_loss = 50.663814544677734
#
# Training step = 600, N_exploration_samples = 1000,
# min_loss = 0.18847976624965668
# med_loss = 2.6640219688415527
# max_loss = 44.02175521850586
#
# Training step = 700, N_exploration_samples = 1000,
# min_loss = 0.1650901585817337
# med_loss = 2.158153533935547
# max_loss = 38.129947662353516
#
# Training step = 800, N_exploration_samples = 1000,
# min_loss = 0.1471756398677826
# med_loss = 1.783347725868225
# max_loss = 32.95096969604492
#
# Training step = 900, N_exploration_samples = 1000,
# min_loss = 0.13389205932617188
# med_loss = 1.4893146753311157
# max_loss = 28.431228637695312
#
# Training step = 1000, N_exploration_samples = 1000,
# min_loss = 0.1242145523428917
# med_loss = 1.2468183040618896
# max_loss = 24.50813865661621
#
# Training step = 1100, N_exploration_samples = 1000,
# min_loss = 0.11718866229057312
# med_loss = 1.0683057308197021
# max_loss = 21.115962982177734
#
# Training step = 1200, N_exploration_samples = 1000,
# min_loss = 0.11205685883760452
# med_loss = 0.9267511367797852
# max_loss = 18.189836502075195
#
# Training step = 1300, N_exploration_samples = 1000,
# min_loss = 0.10825510323047638
# med_loss = 0.8143889307975769
# max_loss = 15.668468475341797
#
# Training step = 1400, N_exploration_samples = 1000,
# min_loss = 0.10536713898181915
# med_loss = 0.715274453163147
# max_loss = 13.496715545654297
#
# Training step = 1500, N_exploration_samples = 1000,
# min_loss = 0.10308312624692917
# med_loss = 0.6368472576141357
# max_loss = 11.627456665039062
#
# Training step = 1600, N_exploration_samples = 1000,
# min_loss = 0.09830345213413239
# med_loss = 0.5648150444030762
# max_loss = 10.022520065307617
#
# Training step = 1700, N_exploration_samples = 1000,
# min_loss = 0.09339549392461777
# med_loss = 0.5076781511306763
# max_loss = 8.651253700256348
#
# Training step = 1800, N_exploration_samples = 1000,
# min_loss = 0.08979951590299606
# med_loss = 0.45898228883743286
# max_loss = 7.48705530166626
#
# Training step = 1900, N_exploration_samples = 1000,
# min_loss = 0.08718890696763992
# med_loss = 0.41813474893569946
# max_loss = 6.504134178161621
#
# Training step = 2000, N_exploration_samples = 1000,
# min_loss = 0.08528685569763184
# med_loss = 0.38498741388320923
# max_loss = 5.676551342010498
#
# Training step = 2100, N_exploration_samples = 1000,
# min_loss = 0.08387793600559235
# med_loss = 0.3532758951187134
# max_loss = 4.9792962074279785
#
# Training step = 2200, N_exploration_samples = 1000,
# min_loss = 0.08280301839113235
# med_loss = 0.32962682843208313
# max_loss = 4.389834403991699
#
# Training step = 2300, N_exploration_samples = 1000,
# min_loss = 0.0819489061832428
# med_loss = 0.3076886236667633
# max_loss = 3.888956308364868
#
# Training step = 2400, N_exploration_samples = 1000,
# min_loss = 0.0812373012304306
# med_loss = 0.2898184657096863
# max_loss = 3.4608678817749023
#
# Training step = 2500, N_exploration_samples = 1000,
# min_loss = 0.08061546087265015
# med_loss = 0.27416062355041504
# max_loss = 3.092824935913086
#
# Training step = 2600, N_exploration_samples = 1000,
# min_loss = 0.08004941046237946
# med_loss = 0.2573954164981842
# max_loss = 2.7746222019195557
#
# Training step = 2700, N_exploration_samples = 1000,
# min_loss = 0.07951975613832474
# med_loss = 0.24074804782867432
# max_loss = 2.498091459274292
#
# Training step = 2800, N_exploration_samples = 1000,
# min_loss = 0.07901739329099655
# med_loss = 0.22744524478912354
# max_loss = 2.25665020942688
#
# Training step = 2900, N_exploration_samples = 1000,
# min_loss = 0.07853813469409943
# med_loss = 0.21681979298591614
# max_loss = 2.044964551925659
#
# Training step = 3000, N_exploration_samples = 1000,
# min_loss = 0.07807890325784683
# med_loss = 0.20593079924583435
# max_loss = 1.8586784601211548
#
# Training step = 3100, N_exploration_samples = 1000,
# min_loss = 0.07763643562793732
# med_loss = 0.19538766145706177
# max_loss = 1.6942012310028076
#
# Training step = 3200, N_exploration_samples = 1000,
# min_loss = 0.07720760256052017
# med_loss = 0.1860455870628357
# max_loss = 1.5485535860061646
#
# Training step = 3300, N_exploration_samples = 1000,
# min_loss = 0.07679014652967453
# med_loss = 0.17887145280838013
# max_loss = 1.4192397594451904
#
# Training step = 3400, N_exploration_samples = 1000,
# min_loss = 0.07638312131166458
# med_loss = 0.17172253131866455
# max_loss = 1.304158329963684
#
# Training step = 3500, N_exploration_samples = 1000,
# min_loss = 0.07598719745874405
# med_loss = 0.16442513465881348
# max_loss = 1.2015290260314941
#
# Training step = 3600, N_exploration_samples = 1000,
# min_loss = 0.0756046324968338
# med_loss = 0.1579354852437973
# max_loss = 1.1098334789276123
#
# Training step = 3700, N_exploration_samples = 1000,
# min_loss = 0.07523884624242783
# med_loss = 0.15255200862884521
# max_loss = 1.027772307395935
#
# Training step = 3800, N_exploration_samples = 1000,
# min_loss = 0.07489386945962906
# med_loss = 0.14670537412166595
# max_loss = 0.954224705696106
#
# Training step = 3900, N_exploration_samples = 1000,
# min_loss = 0.07457339018583298
# med_loss = 0.14315855503082275
# max_loss = 0.8882210850715637
#
# Training step = 4000, N_exploration_samples = 1000,
# min_loss = 0.07427997142076492
# med_loss = 0.1390041559934616
# max_loss = 0.8289164900779724
#
# Training step = 4100, N_exploration_samples = 1000,
# min_loss = 0.0740145891904831
# med_loss = 0.13453027606010437
# max_loss = 0.7755749821662903
#
# Training step = 4200, N_exploration_samples = 1000,
# min_loss = 0.07377655059099197
# med_loss = 0.13022193312644958
# max_loss = 0.7275475263595581
#
# Training step = 4300, N_exploration_samples = 1000,
# min_loss = 0.07356371730566025
# med_loss = 0.126373291015625
# max_loss = 0.6842651963233948
#
# Training step = 4400, N_exploration_samples = 1000,
# min_loss = 0.07337304204702377
# med_loss = 0.12345518171787262
# max_loss = 0.6452240943908691
#
# Training step = 4500, N_exploration_samples = 1000,
# min_loss = 0.07320117205381393
# med_loss = 0.12067030370235443
# max_loss = 0.609976053237915
#
# Training step = 4600, N_exploration_samples = 1000,
# min_loss = 0.07304476946592331
# med_loss = 0.11837340146303177
# max_loss = 0.5927871465682983
#
# Training step = 4700, N_exploration_samples = 1000,
# min_loss = 0.07290102541446686
# med_loss = 0.11584484577178955
# max_loss = 0.5877740979194641
#
# Training step = 4800, N_exploration_samples = 1000,
# min_loss = 0.07276766002178192
# med_loss = 0.11395971477031708
# max_loss = 0.5818875432014465
#
# Training step = 4900, N_exploration_samples = 1000,
# min_loss = 0.07264303416013718
# med_loss = 0.11156929284334183
# max_loss = 0.5746391415596008
#
# Training step = 5000, N_exploration_samples = 1000,
# min_loss = 0.07252602279186249
# med_loss = 0.10970041900873184
# max_loss = 0.5651898980140686
#
# Training step = 5100, N_exploration_samples = 1000,
# min_loss = 0.07241590321063995
# med_loss = 0.10773767530918121
# max_loss = 0.5520662069320679
#
# Training step = 5200, N_exploration_samples = 1000,
# min_loss = 0.0722605437040329
# med_loss = 0.10604970157146454
# max_loss = 0.5328607559204102
#
# Training step = 5300, N_exploration_samples = 1000,
# min_loss = 0.07206465303897858
# med_loss = 0.10441428422927856
# max_loss = 0.5049921274185181
#
# Training step = 5400, N_exploration_samples = 1000,
# min_loss = 0.07189236581325531
# med_loss = 0.10280661284923553
# max_loss = 0.47390347719192505
#
# Training step = 5500, N_exploration_samples = 1000,
# min_loss = 0.07174206525087357
# med_loss = 0.10112038254737854
# max_loss = 0.4673355519771576
#
# Training step = 5600, N_exploration_samples = 1000,
# min_loss = 0.07161156833171844
# med_loss = 0.09960238635540009
# max_loss = 0.46432626247406006
#
# Training step = 5700, N_exploration_samples = 1000,
# min_loss = 0.07149842381477356
# med_loss = 0.09824396669864655
# max_loss = 0.46161141991615295
#
# Training step = 5800, N_exploration_samples = 1000,
# min_loss = 0.07140012830495834
# med_loss = 0.0966002345085144
# max_loss = 0.45913925766944885
#
# Training step = 5900, N_exploration_samples = 1000,
# min_loss = 0.07131429761648178
# med_loss = 0.09526243805885315
# max_loss = 0.4568619132041931
#
# Training step = 6000, N_exploration_samples = 1000,
# min_loss = 0.07123881578445435
# med_loss = 0.09413929283618927
# max_loss = 0.45473402738571167
#
# Training step = 6100, N_exploration_samples = 1000,
# min_loss = 0.07117190212011337
# med_loss = 0.09317513555288315
# max_loss = 0.452712744474411
#
# Training step = 6200, N_exploration_samples = 1000,
# min_loss = 0.07111202925443649
# med_loss = 0.09196236729621887
# max_loss = 0.4507560431957245
#
# Training step = 6300, N_exploration_samples = 1000,
# min_loss = 0.0710580125451088
# med_loss = 0.0908169150352478
# max_loss = 0.44882309436798096
#
# Training step = 6400, N_exploration_samples = 1000,
# min_loss = 0.07100889086723328
# med_loss = 0.08973367512226105
# max_loss = 0.44687095284461975
#
# Training step = 6500, N_exploration_samples = 1000,
# min_loss = 0.07096390426158905
# med_loss = 0.08878816664218903
# max_loss = 0.4448544383049011
#
# Training step = 6600, N_exploration_samples = 1000,
# min_loss = 0.07092239707708359
# med_loss = 0.0879858210682869
# max_loss = 0.44272223114967346
#
# Training step = 6700, N_exploration_samples = 1000,
# min_loss = 0.0708838552236557
# med_loss = 0.08730603754520416
# max_loss = 0.44041377305984497
#
# Training step = 6800, N_exploration_samples = 1000,
# min_loss = 0.07084787636995316
# med_loss = 0.08651121705770493
# max_loss = 0.4378553628921509
#
# Training step = 6900, N_exploration_samples = 1000,
# min_loss = 0.0708141028881073
# med_loss = 0.08593466877937317
# max_loss = 0.43495801091194153
#
# Training step = 7000, N_exploration_samples = 1000,
# min_loss = 0.07078224420547485
# med_loss = 0.08526226878166199
# max_loss = 0.43161654472351074
#
# Training step = 7100, N_exploration_samples = 1000,
# min_loss = 0.07075204700231552
# med_loss = 0.08463440835475922
# max_loss = 0.4277151823043823
#
# Training step = 7200, N_exploration_samples = 1000,
# min_loss = 0.07072329521179199
# med_loss = 0.08394773304462433
# max_loss = 0.42313501238822937
#
# Training step = 7300, N_exploration_samples = 1000,
# min_loss = 0.07069586217403412
# med_loss = 0.08331996202468872
# max_loss = 0.4177633821964264
#
# Training step = 7400, N_exploration_samples = 1000,
# min_loss = 0.07066954672336578
# med_loss = 0.08269783854484558
# max_loss = 0.4114943742752075
#
# Training step = 7500, N_exploration_samples = 1000,
# min_loss = 0.07064422965049744
# med_loss = 0.08216306567192078
# max_loss = 0.40422019362449646
#
# Training step = 7600, N_exploration_samples = 1000,
# min_loss = 0.0706198439002037
# med_loss = 0.081678107380867
# max_loss = 0.39582061767578125
#
# Training step = 7700, N_exploration_samples = 1000,
# min_loss = 0.07059624791145325
# med_loss = 0.08120499551296234
# max_loss = 0.3861611783504486
#
# Training step = 7800, N_exploration_samples = 1000,
# min_loss = 0.0705733597278595
# med_loss = 0.0806635394692421
# max_loss = 0.3750925660133362
#
# Training step = 7900, N_exploration_samples = 1000,
# min_loss = 0.07055114209651947
# med_loss = 0.08021742105484009
# max_loss = 0.3624354302883148
#
# Training step = 8000, N_exploration_samples = 1000,
# min_loss = 0.070529505610466
# med_loss = 0.07972724735736847
# max_loss = 0.3479412794113159
#
# Training step = 8100, N_exploration_samples = 1000,
# min_loss = 0.0705084353685379
# med_loss = 0.07931655645370483
# max_loss = 0.33125749230384827
#
# Training step = 8200, N_exploration_samples = 1000,
# min_loss = 0.0704878568649292
# med_loss = 0.07889686524868011
# max_loss = 0.31196069717407227
#
# Training step = 8300, N_exploration_samples = 1000,
# min_loss = 0.0704677551984787
# med_loss = 0.07852144539356232
# max_loss = 0.30535534024238586
#
# Training step = 8400, N_exploration_samples = 1000,
# min_loss = 0.07044809311628342
# med_loss = 0.07820957899093628
# max_loss = 0.304855078458786
#
# Training step = 8500, N_exploration_samples = 1000,
# min_loss = 0.07042887061834335
# med_loss = 0.07780569046735764
# max_loss = 0.30437928438186646
#
# Training step = 8600, N_exploration_samples = 1000,
# min_loss = 0.07041005790233612
# med_loss = 0.07748174667358398
# max_loss = 0.30392691493034363
#
# Training step = 8700, N_exploration_samples = 1000,
# min_loss = 0.07039165496826172
# med_loss = 0.07714062929153442
# max_loss = 0.3034965395927429
#
# Training step = 8800, N_exploration_samples = 1000,
# min_loss = 0.07037364691495895
# med_loss = 0.07683061063289642
# max_loss = 0.3030869662761688
#
# Training step = 8900, N_exploration_samples = 1000,
# min_loss = 0.07035601884126663
# med_loss = 0.07656405866146088
# max_loss = 0.3026970326900482
#
# Training step = 9000, N_exploration_samples = 1000,
# min_loss = 0.07033879309892654
# med_loss = 0.07627219706773758
# max_loss = 0.3023258447647095
#
# Training step = 9100, N_exploration_samples = 1000,
# min_loss = 0.0703219398856163
# med_loss = 0.07604709267616272
# max_loss = 0.3019721806049347
#
# Training step = 9200, N_exploration_samples = 1000,
# min_loss = 0.07030550390481949
# med_loss = 0.07574135065078735
# max_loss = 0.30163514614105225
#
# Training step = 9300, N_exploration_samples = 1000,
# min_loss = 0.07028944790363312
# med_loss = 0.07551269233226776
# max_loss = 0.3013136684894562
#
# Training step = 9400, N_exploration_samples = 1000,
# min_loss = 0.07027379423379898
# med_loss = 0.07529594004154205
# max_loss = 0.30100691318511963
#
# Training step = 9500, N_exploration_samples = 1000,
# min_loss = 0.07025853544473648
# med_loss = 0.07501879334449768
# max_loss = 0.30071380734443665
#
# Training step = 9600, N_exploration_samples = 1000,
# min_loss = 0.07023971527814865
# med_loss = 0.07482565939426422
# max_loss = 0.30043357610702515
#
# Training step = 9700, N_exploration_samples = 1000,
# min_loss = 0.07021968066692352
# med_loss = 0.0746239423751831
# max_loss = 0.3001652956008911
#
# Training step = 9800, N_exploration_samples = 1000,
# min_loss = 0.07020018994808197
# med_loss = 0.07440710067749023
# max_loss = 0.29990819096565247
#
# Training step = 9900, N_exploration_samples = 1000,
# min_loss = 0.07018116116523743
# med_loss = 0.07423143088817596
# max_loss = 0.29966142773628235

# %%
res = optimizer.outputs
param_history = res['param_history']

# %%
loss_decay = res['loss_decay']
last_epoch = loss_decay[-1]
best = np.where(last_epoch == last_epoch.min())[0][0]
print(f"Index of best parameters: {best}, loss = {last_epoch[best]}")
# Out:
# Index of best parameters: 242, loss = 0.0701904296875

# %%
def minmax_norm(array, lower, upper):
    if (array.max() - array.min()) != 0:
        norm = (array - array.min()) / (array.max() - array.min())
        return lower + (norm * (upper-lower))
    else:
        return array

# %%
fig, ax = plt.subplots(2, figsize = (3,2))

for i, decay in enumerate(loss_decay.T):
    ax[0].plot(decay, alpha = 0.05, color = 'black', linewidth = linewidth)

ax[1].set_xlabel("Training Epoch", fontsize = fontsize)
ax[0].set_ylabel("Loss (MSE)", fontsize = fontsize)
ax[0].set_ylim(0,)
ax[0].set_xticks([])

ax[1].set_ylabel("Loss (MSE)", fontsize = fontsize)
ax[1].plot(loss_decay[:,best], alpha = 1, color = 'black', linewidth = linewidth)
ax[1].set_ylim(0.)
ax[0].set_title("Loss decay over training epochs\n(first round optimization)", fontsize = fontsize)

for i in range(2):
    ax[i].tick_params(labelsize = fontsize)
    ax[i].spines['top'].set_visible(False)
    ax[i].spines['right'].set_visible(False)

figname = '2d_model_loss_decay_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(2,1, figsize = (3, 2))

for i in range(2):
    i_ = np.abs(i-1)
    for u in range(2):
        x = np.linspace(
            list(param_bounds.values())[-1-i][0],
            list(param_bounds.values())[-1-i][1],
            100
        )
        data = param_history['V1_params'][:,-1,u,0,i_,0,0]
        kde = gaussian_kde(data)
        y = kde(x)

        ax[i].plot(x,y, label = f'V1_{u+1}', linewidth = linewidth)
        ax[i].set_xlim(
            list(param_bounds.values())[-1-i][0],
            list(param_bounds.values())[-1-i][1]
        )
        ax[i].set_ylabel("Density", fontsize = fontsize)
        ax[i].spines['top'].set_visible(False)
        ax[i].spines['right'].set_visible(False)
        ax[i].tick_params(labelsize = fontsize)

ax[0].set_xlabel('Inhibition weight', fontsize = fontsize)
ax[1].set_xlabel('Inhibition delay', fontsize = fontsize)
ax[0].legend(fontsize = 6)
fig.subplots_adjust(hspace=1)
plt.suptitle("Distribution of V1 parameters post-optimization\n(first round optimization)", fontsize = fontsize, x = 0.525, y = 1.05)

figname = '2d_model_v1_param_density_func_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(7,2, figsize = (3,7))

param_labels = [
    'Frequency-time slope',
    'Temporal center',
    'Tuning center',
    'Tuning midline',
    'Tuning gain',
    'Tuning bandwidth',
    'Temporal bandwidth'
]

neuron_labels = [f'dLGN_{i+1}' for i in range(3)]


for row in range(7):
    ymax = []
    for i in range(3):
        for u in range(2):
            data = param_history['dLGN_params'][:,-1,u,i,row,0,0]
            x = np.linspace(
                list(param_bounds.values())[:7][row][0],
                list(param_bounds.values())[:7][row][1], 
                100
            )
            kde = gaussian_kde(data)
            y = kde(x)

            ymax.append(y.max())
            
            ax[row, u].plot(x, y, label = neuron_labels[i], linewidth = linewidth)
            ax[row, u].set_xlabel(param_labels[row], fontsize = fontsize)
            ax[row, u].tick_params(labelsize = fontsize)

    ax[row, 0].set_ylabel("Density", fontsize = fontsize)
    for u in range(2):
        ax[row, u].set_ylim(0, np.max(ymax)+np.max(ymax)*0.25)
        ax[row, 1].set_yticks([])
        ax[row, 0].set_yticks(np.linspace(0, np.max(ymax)+np.max(ymax)*0.5, 4).round(2))
        ax[row, u].spines['top'].set_visible(False)
        ax[row, u].spines['right'].set_visible(False)

fig.subplots_adjust(hspace = 2, wspace=0.25)
plt.tick_params(labelsize = 8)
ax[0,1].legend(fontsize = 6, bbox_to_anchor = (1.4,1.1))
ax[0,0].set_title("Inputs to V1-1", fontsize = fontsize, y = 1.25)
ax[0,1].set_title("Inputs to V1-2", fontsize = fontsize, y = 1.25)
plt.suptitle("Distribution of dLGN parameters post-optimization", fontsize = fontsize, x = 0.525, y = 0.975)

figname = '2d_model_dlgn_param_density_func_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
optimizer.save_state('sgcc_mop_3_11_26', write=True)

# %%
## inhibition weight::inhibition delay

fig, ax = plt.subplots(2,2, figsize = (3,2))

inh_w = 1
v1_n = 0 

for row in range(2):
    for col in range(2):
        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

ax[0,0].plot(
    param_history['V1_params'][:,:,v1_n,0,inh_w,0,0].T,
    linewidth=linewidth,
    alpha=0.05,
    color = 'black'
)

# 
v1_n = 1
ax[0,1].plot(
    param_history['V1_params'][:,:,v1_n,0,inh_w,0,0].T,
    linewidth=linewidth,
    alpha=0.05,
    color = 'black'
)

# a0
inh_d = 0
v1_n = 0
ax[1,0].plot(
    param_history['V1_params'][:,:,v1_n,0,inh_d,0,0].T,
    linewidth=linewidth,
    alpha=0.05,
    color = 'black'
)

# a1
v1_n = 1
ax[1,1].plot(
    param_history['V1_params'][:,:,v1_n,0,inh_d,0,0].T,
    linewidth=linewidth,
    alpha=0.05,
    color = 'black'
)

ax[0,0].set_ylim(0,3)
ax[0,0].set_title("V1_1 Inhibition Weight", fontsize = fontsize)
ax[0,0].set_xticks([])
ax[0,0].set_ylabel("Au", fontsize = fontsize)

ax[0,1].set_ylim(0,3)
ax[0,1].set_title("V1_2 Inhibition Weight", fontsize = fontsize)
ax[0,1].set_xticks([])

ax[1,0].set_ylim(0,40)
ax[1,0].set_title("V1_1 Inhibition Delay", fontsize = fontsize)
ax[1,0].set_ylabel("Time (ms)", fontsize = fontsize)
ax[1,0].set_xlabel("Training Epoch", fontsize = fontsize)

ax[1,1].set_ylim(0,40)
ax[1,1].set_title("V1_2 Inhibition Delay", fontsize = fontsize)
ax[1,1].set_xlabel("Training Epoch", fontsize = fontsize)
fig.subplots_adjust(wspace=0.5, hspace=0.5)
plt.suptitle("Convergence of V1 parameter values\n(first round optimization)", fontsize = fontsize, y = 1.15)

figname = '2d_model_v1_param_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 0

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Freq-Time Slopes V1_{i+1}", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Onset/SF", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(20,200)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_fts_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 1

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Onset times V1_{i+1}", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Time (ms)", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(40,150)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_t_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 2

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Tuning center V1_{i+1}", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("c/d", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(0,0.1)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_ampc_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 3

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Tuning midline V1_{i+1}", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Au", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(0,3)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_ampm_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 4

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Amplitude gain", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Au", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(0,4)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_ampg_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 5

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Tuning bandwidth", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Au", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(0,0.1)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_ampw_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
fig, ax = plt.subplots(3,2, figsize = (3,3))
norm = plt.Normalize(0, 1)

param = 6

for col in range(2):
    for row in range(3):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        data = param_history['dLGN_params'][:,:,col,row,param,0,0].T
        ax[row,col].plot(
        param_history['dLGN_params'][:,:,col,row,param,0,0].T,
            linewidth=linewidth,
            alpha=0.05,
            color='black'
        )

for i in range(2):
    ax[0,i].set_title(f"Response duration", fontsize = fontsize)
for i in range(3):
    ax[i,0].set_ylabel("Time (ms)", fontsize = fontsize)
for row in range(2):
    for col in range(2):
        ax[row,col].set_xticks([])
for row in range(3):
    for col in range(2):
        ax[row,col].set_ylim(10,40)
for i in range(2):
    ax[2,i].set_xlabel("Training Epoch", fontsize = fontsize)

fig.subplots_adjust(wspace=0.5, hspace=0.5)

figname = '2d_model_d_convergence_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
res = param_history['dLGN_params'].squeeze()
print(res.shape[2:])
n_samples, n_epochs = res.shape[:2]
n_params = np.prod(res.shape[2:])# + np.prod(r2.shape[2:])

res = res.reshape(res.shape[0] * res.shape[1], np.prod(res.shape[2:]))
# Out:
# (2, 3, 7)

# %%
pca = PCA() # all epochs included
res_transformed_pca = pca.fit_transform(res).reshape(n_samples, n_epochs, n_params)

# %%
fig, ax = plt.subplots(2,5, figsize = (7,2))

comp_pairs = (list(combinations(np.arange(6), 2)))
i = 0
for row in range(2):
    for col in range(5):

        ax[row, col].spines['top'].set_visible(False)
        ax[row, col].spines['right'].set_visible(False)
        ax[row, col].tick_params(labelsize = fontsize)

        c0, c1 = comp_pairs[i]
        ax[row, col].scatter(res_transformed_pca[:,-1,c0], res_transformed_pca[:,-1,c1], s = 0.1) # last epoch
        ax[row, col].set_title(f"Comp {c0+1} vs. comp {c1+1}", fontsize = fontsize)
        i+=1

fig.subplots_adjust(hspace = 0.75, wspace = 1.5)
figname = '2d_model_pcaprojection_first_round.svg'
savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
plt.savefig(savepath, transparent = False, facecolor = 'white',
           bbox_inches = 'tight', dpi = 300)

# %%
lgn_params = [
    'Frequency-time slope',
    'Onset time',
    'Tuning center',
    'Tuning midline',
    'Tuning gain',
    'Tuning bandwidth',
    'Response duration'
]

v1_params = [
    'Inhibition delay',
    'Inhibition weight'
]

lgn_units = [
    'dLGN_1 into V1_1',
    'dLGN_2 into V1_1',
    'dLGN_3 into V1_1',
    'dLGN_1 into V1_2',
    'dLGN_2 into V1_2',
    'dLGN_3 into V1_2',
]

v1_units = [
    'V1_1',
    'V1_2'
]

full_lgn_params = []
for unit in lgn_units:
    for param in lgn_params:
        full_lgn_params.append(f"{param} ({unit})")

full_v1_params = []
for unit in v1_units:
    for param in v1_params:
        full_v1_params.append(f"{param} ({unit})")
        
param_names = full_lgn_params+full_v1_params

# %%
for i in range(10):
    fig, ax = plt.subplots(figsize = (8, 4))
    ax.tick_params(labelsize = fontsize)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.bar(np.arange(len(full_lgn_params)), np.abs(pca.components_[i]))
    ax.set_xticks(np.arange(len(full_lgn_params)))
    ax.set_xticklabels(param_names[:len(full_lgn_params)], rotation = 90)
    ax.set_ylabel("Loading scores", fontsize = fontsize)
    ax.set_title(f"Component {i+1}", fontsize = fontsize)

    figname = f'2d_model_pca_loadings_pc{i+1}_first_round.svg'
    savepath = v1_xs_file = os.path.join('c:\\', *os.getcwd().split('\\')[1:-1], 'figures', figname)
    plt.savefig(savepath, transparent = False, facecolor = 'white',
            bbox_inches = 'tight', dpi = 300)
